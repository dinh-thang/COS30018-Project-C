# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# !pip install --upgrade transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
import torch
import torch.nn as nn
from transformers import AutoModelForQuestionAnswering

model = AutoModelForQuestionAnswering.from_pretrained("hung200504/bert-covid-10", trust_remote_code=True)

#Freeze all layers
for param in model.parameters():
    param.requires_grad = False

#Unfreeze qa_ouputs layers
for param in model.qa_outputs.parameters():
    param.requires_grad = True

# %%
from datasets import load_dataset

dataset = load_dataset("minh21/cpgQA-v1.0-unique-context", split = "train")
eval_dataset = load_dataset("minh21/cpgQA-v1.0-unique-context", split = "test")
# Out:
# Downloading readme:   0%|          | 0.00/732 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/147k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/43.9k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/871 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/226 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("hung200504/bert-covid-10", trust_remote_code=True)

# %%
def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answer_text"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = examples["answer_start"][0]
        end_char = examples["answer_start"][0] + len(examples["answer_text"])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label it (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

dataset = dataset.map(preprocess_function, batched=True, remove_columns=dataset.column_names)
eval_dataset = eval_dataset.map(preprocess_function, batched=True, remove_columns=eval_dataset.column_names)
# Out:
# Map:   0%|          | 0/871 [00:00<?, ? examples/s]
# Map:   0%|          | 0/226 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'start_positions', 'end_positions'],
#     num_rows: 871
# })

# %%
# Import the TrainingArguments class from the transformers library
from transformers import TrainingArguments

# Create an instance of TrainingArguments with the following parameters:
training_args = TrainingArguments(
    "bert-covid-10",  # The output directory where the model predictions and checkpoints will be written.

    per_device_train_batch_size = 16,  # Batch size for training.
    per_device_eval_batch_size = 16,  # Batch size for evaluation.

    evaluation_strategy="steps",  # Evaluation is done (and logged) every `eval_steps`.
    save_strategy="epoch",  # The model checkpoint is saved at the end of each epoch.

    learning_rate=3e-5,  # Learning rate for the optimizer.

    do_eval=True,  # Whether to run evaluation during training.

    eval_steps = 5,  # Number of update steps between two evaluations.

    num_train_epochs=1,  # Total number of training epochs to perform.

    logging_steps=5,  # Number of update steps between two logs.

    fp16=True,  # Whether to use 16-bit (mixed) precision training instead of 32-bit training.
)

# %%
from transformers import Trainer
import torch


trainer = Trainer(
    model=model,
    args=training_args,
    eval_dataset=eval_dataset,
    train_dataset=dataset,
    tokenizer=tokenizer,
)

# %% [markdown]
# 4311af5440e688d6054079f35d07feb6669756be

# %%
trainer.train()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231021_175350-yo7i7vqv</code>
# Syncing run <strong><a href='https://wandb.ai/hungnguyennguyen200504/huggingface/runs/yo7i7vqv' target="_blank">distinctive-firebrand-160</a></strong> to <a href='https://wandb.ai/hungnguyennguyen200504/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hungnguyennguyen200504/huggingface' target="_blank">https://wandb.ai/hungnguyennguyen200504/huggingface</a>
#  View run at <a href='https://wandb.ai/hungnguyennguyen200504/huggingface/runs/yo7i7vqv' target="_blank">https://wandb.ai/hungnguyennguyen200504/huggingface/runs/yo7i7vqv</a>
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='55' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [55/55 00:13, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>10.291600</td>
#       <td>11.552251</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>10.199400</td>
#       <td>11.494240</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>9.762100</td>
#       <td>11.442470</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>10.082800</td>
#       <td>11.396930</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>9.980600</td>
#       <td>11.356741</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>10.091300</td>
#       <td>11.322533</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>9.499800</td>
#       <td>11.294442</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>9.418800</td>
#       <td>11.272215</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>9.795500</td>
#       <td>11.256088</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>9.620100</td>
#       <td>11.245460</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>9.894600</td>
#       <td>11.240786</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=55, training_loss=9.876051191850141, metrics={'train_runtime': 30.9171, 'train_samples_per_second': 28.172, 'train_steps_per_second': 1.779, 'total_flos': 170692106337792.0, 'train_loss': 9.876051191850141, 'epoch': 1.0})

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#Push model to hub
trainer.push_to_hub("bert-cased")
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/4.54k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# 'https://huggingface.co/hung200504/test-bert-4/tree/main/'

# %%
from transformers import  pipeline

pipeline = pipeline("question-answering", model="bioformers/bioformer-litcovid", tokenizer="bioformers/bioformer-litcovid")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]

# %%
# Initialize total F1 score and accuracy to 0
total_f1 = 0
total_accuracy = 0

# Loop through each instance in the evaluation dataset
for ins in eval_dataset:
  # Generate an answer using a pipeline with the question and context from the instance
  ans = pipeline(question=ins['question'], context=ins['context'], max_answer_len=50, max_question_len=300)

  # Tokenize the reference answer and the generated answer
  ref_tokens = tokenizer(" " + ins["answer_text"])["input_ids"]
  ans_tokens = tokenizer(ans["answer"])["input_ids"]

  # Find the common tokens between the reference answer and the generated answer
  common_tokens = set(ans_tokens) & set(ref_tokens)

  # Calculate precision and recall
  precision = len(common_tokens) / len(ans_tokens)
  recall = len(common_tokens) / len(ref_tokens)

  # Add the precision to the total accuracy
  total_accuracy += precision

  # Print the decoded tokens of the generated answer and reference answer
  print(tokenizer.decode(ans_tokens), "|", tokenizer.decode(ref_tokens), "|")

  # If there are no common tokens, add 0 to the total F1 score, else calculate F1 score and add it to the total F1 score
  if (len(common_tokens) == 0):
    total_f1 += 0
    print(0)
  else:
    f1 = 2 * precision * recall / (precision + recall)
    total_f1 += f1
    print(f1)

# Print the average F1 score and accuracy
print("F1 average score:", total_f1 / eval_dataset.num_rows)
print("Accuracy average score: ", total_accuracy / eval_dataset.num_rows)
# Out:
# [CLS] are lung disease, sleep apnea, liver disease, renal disease [SEP] | [CLS] lung disease, sleep apnea, liver disease, renal disease, fall risk, advanced age [SEP] |
# 0.5454545454545454
# [CLS] consider tapering opioids [SEP] | [CLS] consider tapering opioids [SEP] |
# 1.0
# [CLS] ptsd, depression, anxiety [SEP] | [CLS] ptsd, depression, anxiety [SEP] |
# 0.8571428571428571
# [CLS] discuss the risks of continued use [SEP] | [CLS] the risks of continued use, along with possible benefits [SEP] |
# 0.7000000000000001
# [CLS] alcohol use disorder ( aud ), opioid use disorder ( oud ), and / or a use disorder involving other substances [SEP] | [CLS] alcohol use disorder ( aud ), opioid use disorder ( oud ), and / or a use disorder involving other substances [SEP] |
# 0.7307692307692306
# [CLS] benzodiazepines [SEP] | [CLS] benzodiazepines [SEP] |
# 1.0
# [CLS] special attention [SEP] | [CLS] special attention must be given to ensure that the veteran does not feel abandoned [SEP] |
# 0.38095238095238093
# [CLS] when a decision is made to taper [SEP] | [CLS] when a decision is made to taper [SEP] |
# 1.0
# [CLS] a discussion [SEP] | [CLS] a discussion should occur between the veteran, family members / caregivers, and the provider either during a face - to - face appointment or on the telephone [SEP] |
# 0.2222222222222222
# [CLS] the veteran, family members / caregivers, and the provider [SEP] | [CLS] the veteran, family members / caregivers, and the provider [SEP] |
# 0.8571428571428571
# [CLS] any changes being made in opioid prescribing [SEP] | [CLS] any changes being made in opioid prescribing [SEP] |
# 1.0
# [CLS] discussion, asking about goals, educating the veteran [SEP] | [CLS] discussion, asking about goals, educating the veteran [SEP] |
# 0.9230769230769231
# [CLS] family members or other supporters [SEP] | [CLS] listening to the veteran ’ s story, letting the veteran know that you believe that their pain is real, using motivational interviewing ( mi ) techniques to acknowledge the veteran ’ s fears about tapering [SEP] |
# 0.07547169811320754
# [CLS] family members or other supporters [SEP] | [CLS] family members or other supporters [SEP] |
# 1.0
# [CLS] motivational interviewing ( mi ) techniques [SEP] | [CLS] motivational interviewing ( mi ) [SEP] |
# 0.9333333333333333
# [CLS] acknowledge the veteran ’ s fears about tapering [SEP] | [CLS] to acknowledge the veteran ’ s fears about tapering [SEP] |
# 0.962962962962963
# [CLS] just being pain - free [SEP] | [CLS] just being pain - free [SEP] |
# 1.0
# [CLS] the personal health inventory [SEP] | [CLS] personal health inventory [SEP] |
# 0.9090909090909091
# [CLS] over days [SEP] | [CLS] over days [SEP] |
# 1.0
# [CLS] 10 to 20 % [SEP] | [CLS] by 20 to 50 % of first dose if needed, then reduce by 10 to 20 % every day [SEP] |
# 0.42857142857142855
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] |
# 0.9285714285714286
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 45 mg sr ( 15 mg x 3 ) q8h [SEP] |
# 0.7857142857142857
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 30 mg sr ( 15 mg x 2 ) q8h [SEP] |
# 0.7857142857142857
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr q8h [SEP] |
# 0.7272727272727273
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr q12h [SEP] |
# 0.5454545454545454
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr q12h [SEP] |
# 0.5454545454545454
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr q12h [SEP] |
# 0.5454545454545454
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr qhs [SEP] |
# 0.5714285714285714
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr qhs [SEP] |
# 0.5714285714285714
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr qhs [SEP] |
# 0.5714285714285714
# [CLS] 60 mg sr ( 15 mg x 4 ) q8h [SEP] | [CLS] 15 mg sr qhs [SEP] |
# 0.5714285714285714
# [CLS] after day 11 and may consider morphine ir 15 mg ½ tablet ( 7. 5 mg ) twice daily [SEP] | [CLS] after day 11 [SEP] |
# 0.37037037037037035
# [CLS] morphine ir 15 mg ½ tablet ( 7. 5 mg ) twice daily [SEP] | [CLS] morphine ir 15 mg ½ tablet ( 7. 5 mg ) twice daily [SEP] |
# 0.9375
# [CLS] rapid tapers [SEP] | [CLS] rapid tapers [SEP] |
# 1.0
# [CLS] withdrawal effects [SEP] | [CLS] withdrawal effects [SEP] |
# 1.0
# [CLS] adjunctive medications [SEP] | [CLS] patients should be treated with adjunctive medications [SEP] |
# 0.6153846153846153
# [CLS] admitting the patient for inpatient care [SEP] | [CLS] admitting the patient for inpatient care [SEP] |
# 1.0
# [CLS] medical history, mental health diagnoses, and patient preference [SEP] | [CLS] medical history, mental health diagnoses, and patient preference [SEP] |
# 0.9166666666666666
# [CLS] based on medical history, mental health diagnoses, and patient preference [SEP] | [CLS] if patients are prescribed both long - acting and short - acting opioids [SEP] |
# 0.20689655172413796
# [CLS] to reduce the dose of morphine to sr 30 mg every 8 hours using a slow taper. dose will be reduced by 15 mg every 10 days [SEP] | [CLS] 15 mg every 10 days [SEP] |
# 0.37837837837837834
# [CLS] 4 tablets = 60 mg [SEP] | [CLS] 4 tablets = 60 mg in the morning, 3 tablets = 45 mg in the afternoon, 4 tablets = 60 mg in the evening [SEP] |
# 0.4
# [CLS] 3 tablets = 45 mg [SEP] | [CLS] 3 tablets = 45 mg in the morning, 3 tablets = 45 mg in the afternoon, 4 tablets = 60 mg in the evening [SEP] |
# 0.4
# [CLS] 3 tablets = 45 mg [SEP] | [CLS] 3 tablets = 45 mg in the morning, 3 tablets = 45 mg in the afternoon, 3 tablets = 45 mg in the evening [SEP] |
# 0.4
# [CLS] veteran [SEP] | [CLS] pact team [SEP] |
# 0.4444444444444445
# [CLS] a team function [SEP] | [CLS] a team function with various team members taking on roles in which they have demonstrated specific competencies [SEP] |
# 0.4166666666666667
# [CLS] with various team members [SEP] | [CLS] follow - up for tapering [SEP] |
# 0.28571428571428575
# [CLS] mental health practitioners [SEP] | [CLS] mental health practitioners [SEP] |
# 1.0
# [CLS] 1 to 4 weeks [SEP] | [CLS] 1 to 4 weeks after starting taper then monthly before each reduction [SEP] |
# 0.6
# [CLS] monthly before each reduction. during the faster taper, follow up with the veteran weekly before each dose reduction. during the rapid taper, follow up with the veteran daily before each dose reduction or if available offer inpatient admission. [SEP] | [CLS] 1 to 4 weeks after starting taper then monthly before each reduction [SEP] |
# 0.22950819672131148
# [CLS] weekly [SEP] | [CLS] weekly before each dose reduction [SEP] |
# 0.6
# [CLS] daily [SEP] | [CLS] daily before each dose reduction or if available offer inpatient admission [SEP] |
# 0.375
# [CLS] in the clinic and / or over telephone [SEP] | [CLS] in the clinic and / or over telephone [SEP] |
# 1.0
# [CLS]. [SEP] | [CLS] in the clinic and / or over telephone [SEP] |
# 0.30769230769230765
# [CLS] weekly before each dose reduction. during the rapid taper, follow up with the veteran daily before each dose reduction or if available offer inpatient admission. [SEP] | [CLS] in the clinic and / or over telephone [SEP] |
# 0.1951219512195122
# [CLS] in the hospital, clinic or over telephone [SEP] | [CLS] in the hospital, clinic or over telephone [SEP] |
# 1.0
# [CLS] the risk category of the veteran [SEP] | [CLS] the risk category of the veteran [SEP] |
# 0.8888888888888888
# [CLS] providers [SEP] | [CLS] providers [SEP] |
# 1.0
# [CLS] a veteran [SEP] | [CLS] a veteran with high risk due to a medical condition [SEP] |
# 0.5555555555555556
# [CLS] a veteran [SEP] | [CLS] a veteran with high risk due to a medical condition [SEP] |
# 0.5555555555555556
# [CLS] issues with the veteran obtaining outside prescriptions or they are displaying other aberrant behaviors [SEP] | [CLS] providing follow - up in a clinic visit may be more optimal than a telephone visit [SEP] |
# 0.11428571428571428
# [CLS]. [SEP] | [CLS] providing follow - up in a clinic visit may be more optimal than a telephone visit [SEP] |
# 0.1904761904761905
# [CLS] follow up on patient function, pain intensity, sleep, physical activity, personal goals, and stress level [SEP] | [CLS] patient function, pain intensity, sleep, physical activity, personal goals, and stress level [SEP] |
# 0.7317073170731707
# [CLS] short - term oral medications [SEP] | [CLS] short - term oral medications [SEP] |
# 1.0
# [CLS] with an opioid or benzodiazepine [SEP] | [CLS] an opioid or benzodiazepine [SEP] |
# 0.923076923076923
# [CLS] with a gradual taper [SEP] | [CLS] with a gradual taper [SEP] |
# 1.0
# [CLS] hours to days [SEP] | [CLS] hours to days [SEP] |
# 1.0
# [CLS] days to weeks [SEP] | [CLS] days to weeks [SEP] |
# 1.0
# [CLS] weeks to months [SEP] | [CLS] weeks to months [SEP] |
# 1.0
# [CLS] anxiety / restlessness, rapid short respirations, runny nose, tearing eyes, sweating, insomnia, and dilated reactive pupils [SEP] | [CLS] anxiety / restlessness, rapid short respirations, runny nose, tearing eyes, sweating, insomnia, and dilated reactive pupils [SEP] |
# 0.7931034482758621
# [CLS] runny nose, tearing eyes, rapid breathing, yawning, tremor, diffuse muscle spasms / aches [SEP] | [CLS] runny nose, tearing eyes, rapid breathing, yawning, tremor, diffuse muscle spasms / aches, piloerection, nausea, vomiting, and diarrhea, abdominal pain, fever, chills, increased white blood cells if sudden withdrawal [SEP] |
# 0.5185185185185185
# [CLS] irritability, fatigue, bradycardia, decreased body temperature, craving, insomnia [SEP] | [CLS] irritability, fatigue, bradycardia, decreased body temperature, craving, insomnia [SEP] |
# 0.7333333333333333
# [CLS] 5 to 10 days [SEP] | [CLS] 5 to 10 days following opioid dose reduction / cessation but may take longer depending on the half - life of the opioid ( e. g., methadone ) [SEP] |
# 0.3076923076923077
# [CLS] dysphoria, insomnia and prolonged craving [SEP] | [CLS] dysphoria, insomnia [SEP] |
# 0.8
# [CLS] fatigue, mental functioning, pain, and well - being [SEP] | [CLS] fatigue, mental functioning, pain, and well - being [SEP] |
# 0.8461538461538461
# [CLS] a systematic review of both clinical and epidemiological evidence [SEP] | [CLS] a systematic review of both clinical and epidemiological evidence [SEP] |
# 1.0
# [CLS] a panel of multidisciplinary experts [SEP] | [CLS] a panel of multidisciplinary experts [SEP] |
# 1.0
# [CLS] a clear explanation of the logical relationships between various care options and health outcomes while rating both the quality of the evidence and the strength of the recommendation [SEP] | [CLS] provides a clear explanation of the logical relationships between various care options and health outcomes while rating both the quality of the evidence and the strength of the recommendation [SEP] |
# 0.7540983606557377
# [CLS] to improve the patient ’ s health and well - being [SEP] | [CLS] to improve the patient ’ s health and well - being by providing evidence - based guidance to providers who are taking care of patients on or being considered for lot [SEP] |
# 0.5652173913043478
# [CLS] providing evidence - based guidance [SEP] | [CLS] by providing evidence - based guidance to providers who are taking care of patients on or being considered for lot [SEP] |
# 0.4827586206896552
# [CLS] to assess the patient ’ s condition [SEP] | [CLS] to assess the patient ’ s condition, provide education, and determine the best treatment methods in collaboration with the patient and a multidisciplinary care team, optimize the patient ’ s health outcomes and function and improve quality of life, minimize preventable complications and morbidity, emphasize the use of patient - centered care [SEP] |
# 0.2647058823529412
# [CLS] tapering to reduced dose or to discontinuation [SEP] | [CLS] tapering to reduced dose or to discontinuation of long - term opioid therapy [SEP] |
# 0.6923076923076923
# [CLS] when risks of long - term opioid therapy outweigh benefits [SEP] | [CLS] when risks of long - term opioid therapy outweigh benefits [SEP] |
# 1.0
# [CLS] abrupt discontinuation [SEP] | [CLS] abrupt discontinuation [SEP] |
# 1.0
# [CLS] risk assessment and patient needs and characteristics [SEP] | [CLS] risk assessment and patient needs and characteristics [SEP] |
# 0.8888888888888888
# [CLS] understanding of the clinical pathway and decision making process used in management of lot. [SEP] | [CLS] facilitate understanding of the clinical pathway and decision making process used in management of lot [SEP] |
# 0.8823529411764706
# [CLS] the understanding that such a format may promote more efficient diagnostic and therapeutic decision making and has the potential to change patterns of resource use [SEP] | [CLS] the understanding that such a format may promote more efficient diagnostic and therapeutic decision making and has the potential to change patterns of resource use [SEP] |
# 0.9259259259259259
# [CLS] that not all clinical practices are linear [SEP] | [CLS] not all clinical practices are linear [SEP] |
# 0.9411764705882353
# [CLS] the provider to assess the critical information needed at the major decision points in the clinical process [SEP] | [CLS] to assess the critical information needed at the major decision points in the clinical process [SEP] |
# 0.8333333333333333
# [CLS] the provider [SEP] | [CLS] the provider [SEP] |
# 1.0
# [CLS] an ordered sequence of steps of care [SEP] | [CLS] an ordered sequence of steps of care, recommended observations and examinations, decisions to be considered, actions to be taken [SEP] |
# 0.48484848484848486
# [CLS] there has been limited research on the effectiveness of lot for non - end - of - life pain. [SEP] | [CLS] limited [SEP] |
# 0.24000000000000002
# [CLS] increased mortality, oud, overdose, sexual dysfunction, fractures, myocardial infarction, constipation, and sleep - disordered breathing [SEP] | [CLS] increased mortality, oud, overdose, sexual dysfunction, fractures, myocardial infarction, constipation, and sleep - disordered breathing [SEP] |
# 0.76
# [CLS] 259 million [SEP] | [CLS] 259 million [SEP] |
# 1.0
# [CLS] the osi toolkit and the patient guide “ taking opioids responsibly for your safety and the safety of others : patient information guide on long - term opioid therapy for chronic pain ”. [SEP] | [CLS] osi toolkit and the patient guide “ taking opioids responsibly for your safety and the safety of others : patient information guide on long - term opioid therapy for chronic pain ” [SEP] |
# 0.8108108108108109
# [CLS] to provide clinicians with materials to inform clinical decision - making regarding opioid therapy and safe opioid prescribing [SEP] | [CLS] provide clinicians with materials to inform clinical decision - making regarding opioid therapy and safe opioid prescribing [SEP] |
# 0.9230769230769231
# [CLS] at the following link : https : / / www. va. gov [SEP] | [CLS] https : / / www. va. gov / painmanagement / opioid _ safety _ initiative _ toolkit. asp [SEP] |
# 0.43902439024390244
# [CLS] aimed at providing information [SEP] | [CLS] providing information to patients as well as their providers regarding the safe use of opioids [SEP] |
# 0.3478260869565218
# [CLS] at the following link : http : / / www. healthquality. va. gov / guidelines / pain / cot / opiodtheraphyforchronicpainpatienttool20may20 13print. pdf. [SEP] | [CLS] http : / / www. healthquality. va. gov / guidelines / pain / cot / opiodtheraphyforchronicpainpatienttool20may20 13print. pdf [SEP] |
# 0.7608695652173914
# [CLS] the vha [SEP] | [CLS] the vha [SEP] |
# 1.0
# [CLS] to further promote safety and patient centered care, the vha issued a policy in 2014 [SEP] | [CLS] to further promote safety and patient centered care [SEP] |
# 0.6896551724137931
# [CLS] 2014 [SEP] | [CLS] in 2014 [SEP] |
# 0.8571428571428571
# [CLS] requiring standardized education and signature informed consent [SEP] | [CLS] standardized education and signature informed consent for all patients receiving lot for non - cancer pain [SEP] |
# 0.5925925925925926
# [CLS] executive departments and agencies [SEP] | [CLS] executive departments and agencies shall, to the extent permitted by law, provide training on the appropriate and effective prescribing of opioid medications to all employees who are health care professionals and who prescribe controlled substances as part of their federal responsibilities and duties [SEP] |
# 0.2222222222222222
# [CLS] executive departments and agencies [SEP] | [CLS] the presidential memorandum of october 2015 [SEP] |
# 0.21052631578947367
# [CLS] executive departments and agencies [SEP] | [CLS] the presidential memorandum of october 2015 [SEP] |
# 0.21052631578947367
# [CLS] modules on pain management and opioid prescribing safety [SEP] | [CLS] modules on pain management and opioid prescribing safety, the recent centers for disease control and prevention ( cdc ) guideline, and the identification of substance misuse and referral to specialized services [SEP] |
# 0.4444444444444445
# [CLS] dod opioid prescriber safety training program [SEP] | [CLS] dod opioid prescriber safety training program [SEP] |
# 1.0
# [CLS] defense centers of excellence for psychological health and traumatic brain injury [SEP] | [CLS] defense centers of excellence for psychological health and traumatic brain injury [SEP] |
# 1.0
# [CLS] includes modules on pain management and opioid prescribing safety, the recent centers for disease control and prevention ( cdc ) guideline, and the identification of substance misuse and referral to specialized services. defense centers of excellence for psychological health and traumatic brain injury [SEP] | [CLS] http : / / opstp. cds. pesgce. com / hub. php [SEP] |
# 0.08823529411764706
# [CLS] primary care physicians [SEP] | [CLS] primary care physicians [SEP] |
# 1.0
# [CLS] march 15, 2016 [SEP] | [CLS] march 15, 2016 [SEP] |
# 1.0
# [CLS] to assist primary care providers in offering safe and effective treatment for patients with chronic pain in the outpatient setting [SEP] | [CLS] assist primary care providers in offering safe and effective treatment for patients with chronic pain in the outpatient setting ( not including active cancer treatment, palliative care, or end - of - life care ). it is also aimed at improving communication between providers and patients and decreasing adverse outcomes associated with lot. [SEP] |
# 0.4938271604938271
# [CLS] topics including initiation and continuation of ot, management of ot, and risk assessment and use of risk mitigation strategies [SEP] | [CLS] initiation and continuation of ot, management of ot, and risk assessment and use of risk mitigation strategies [SEP] |
# 0.6363636363636365
# [CLS] grade system [SEP] | [CLS] grade system [SEP] |
# 1.0
# [CLS] strength for each recommendation [SEP] | [CLS] assessment of the quality of the evidence and consideration of the balance of desirable and undesirable outcomes, patient values and preferences, and other considerations ( e. g., resource use, equity ) during recommendation development [SEP] |
# 0.125
# [CLS] comprehensive addiction and recovery act [SEP] | [CLS] the comprehensive addiction and recovery act [SEP] |
# 0.9333333333333333
# [CLS] july 22, 2016 [SEP] | [CLS] july 22, 2016 [SEP] |
# 1.0
# [CLS] addressing the epidemic of overdoses [SEP] | [CLS] addressing the epidemic of overdoses from prescription opioids and other prescription drugs and heroin [SEP] |
# 0.6399999999999999
# [CLS] opioid abuse treatment and prevention [SEP] | [CLS] opioid abuse treatment and prevention [SEP] |
# 1.0
# [CLS] chronic pain [SEP] | [CLS] chronic pain [SEP] |
# 1.0
# [CLS] chronic pain [SEP] | [CLS] chronic pain [SEP] |
# 1.0
# [CLS] chronic pain [SEP] | [CLS] chronic pain [SEP] |
# 1.0
# [CLS] approximately 100 million [SEP] | [CLS] approximately 100 million [SEP] |
# 1.0
# [CLS] the late 1990s and early 2000s [SEP] | [CLS] the late 1990s and early 2000s [SEP] |
# 1.0
# [CLS] the late 1990s and early 2000s [SEP] | [CLS] the late 1990s and early 2000s [SEP] |
# 1.0
# [CLS] approximately one in five [SEP] | [CLS] approximately one in five [SEP] |
# 1.0
# [CLS] quadrupled [SEP] | [CLS] quadrupled [SEP] |
# 1.0
# [CLS] four - fold since 2000, including by 14 % [SEP] | [CLS] four - fold [SEP] |
# 0.5882352941176471
# [CLS] four - fold since 2000, including by 14 % [SEP] | [CLS] 14 % [SEP] |
# 0.5
# [CLS] 183, 000 [SEP] | [CLS] more than 183, 000 [SEP] |
# 0.8333333333333333
# [CLS] the duration and dose of opioid analgesic use [SEP] | [CLS] the duration and dose of opioid analgesic use [SEP] |
# 1.0
# [CLS] given the insufficient evidence of benefit for lot, the clinician must carefully weigh harms and benefits and educate the patient as well as his or her family or caregiver prior to proceeding with treatment. [SEP] | [CLS] given the insufficient evidence of benefit for lot [SEP] |
# 0.4081632653061224
# [CLS]. [SEP] | [CLS] as patient values and preferences may be impacted by other clinical considerations, some patients with one or more risk factors for adverse outcomes may differ with the clinician ’ s assessment that the risks of ot outweigh the potential for modest short - term benefits. [SEP] |
# 0.11538461538461538
# [CLS] ongoing assessment of risk [SEP] | [CLS] should be carefully monitored, and ongoing assessment of risk should be performed with vigilance for the development of additional risk factors and adverse outcomes [SEP] |
# 0.3636363636363636
# [CLS] consultation with appropriate specialty care providers [SEP] | [CLS] consider consultation with appropriate specialty care providers [SEP] |
# 0.9411764705882353
# [CLS] that drug diversion is a crime and constitutes an absolute contraindication to prescribing additional medications [SEP] | [CLS] that drug diversion is a crime and constitutes an absolute contraindication to prescribing additional medications [SEP] |
# 1.0
# [CLS] drug diversion [SEP] | [CLS] drug diversion [SEP] |
# 1.0
# [CLS] because suspicion is subjective and may be based on impression, bias, or prejudice [SEP] | [CLS] because suspicion is subjective and may be based on impression, bias, or prejudice [SEP] |
# 0.9473684210526315
# [CLS] objective evidence [SEP] | [CLS] objective [SEP] |
# 0.8571428571428571
# [CLS] a negative mass spectrometry / liquid chromatography udt [SEP] | [CLS] by a negative mass spectrometry / liquid chromatography udt for the substance being prescribed in the absence of withdrawal symptoms in someone who is receiving opioids [SEP] |
# 0.5499999999999999
# [CLS] a negative udt for the prescribed opioid [SEP] | [CLS] a negative udt for the prescribed opioid [SEP] |
# 1.0
# [CLS] routine udt [SEP] | [CLS] routine udt [SEP] |
# 1.0
# [CLS] e. g., methadone, fentanyl, tramadol [SEP] | [CLS] methadone, fentanyl, tramadol [SEP] |
# 0.6666666666666667
# [CLS] oxycodone, hydrocodone, hydromorphone [SEP] | [CLS] oxycodone, hydrocodone, hydromorphone [SEP] |
# 0.9333333333333333
# [CLS], discontinue opioids [SEP] | [CLS] discontinue opioids according to recommendations 14 and 15 and assess for underlying oud and / or psychiatric comorbidities [SEP] |
# 0.35714285714285715
# [CLS] when there is evidence that the patient is diverting opioids, discontinue opioids according to recommendations 14 and 15 and assess for underlying oud and / or psychiatric comorbidities. [SEP] | [CLS] when there is evidence that the patient is diverting opioids [SEP] |
# 0.5000000000000001
# [CLS] consultation with local risk management and / or counsel. [SEP] | [CLS] when there is evidence that the patient is diverting opioids [SEP] |
# 0.16
# [CLS] that sudden discontinuation of opioids [SEP] | [CLS] sudden discontinuation of opioids due to suspected diversion may place them at high risk for illicit opioid use and resulting opioid overdose ( see recommendation 17 ) [SEP] |
# 0.33333333333333326
# [CLS] psychological therapies [SEP] | [CLS] psychological therapies ( e. g., cognitive behavioral interventions such as cognitive behavioral therapy [ cbt ], biofeedback ) [SEP] |
# 0.2666666666666667
# [CLS] pain reduction [SEP] | [CLS] effective for pain reduction in multiple pain conditions [SEP] |
# 0.5714285714285715
# [CLS] cognitive behavioral interventions such as cognitive behavioral therapy [ cbt ], biofeedback [SEP] | [CLS] cognitive behavioral interventions such as cognitive behavioral therapy [ cbt ], biofeedback [SEP] |
# 0.8823529411764706
# [CLS] exercise treatments, including yoga [SEP] | [CLS] exercise treatments, including yoga [SEP] |
# 1.0
# [CLS] reduction in fear - avoidance, reduction in catastrophizing, and / or enhancing mood [SEP] | [CLS] exercise and psychological therapies may each exert their influence through multiple mechanisms including but not limited to the reduction in fear - avoidance, reduction in catastrophizing, and / or enhancing mood. [SEP] |
# 0.5454545454545455
# [CLS] multidisciplinary biopsychosocial rehabilitation [SEP] | [CLS] multidisciplinary biopsychosocial rehabilitation ( described as a combination of a physical intervention such as graded exercise and a psychological, social, or occupational intervention ) [SEP] |
# 0.43902439024390244
# [CLS] a combination of a physical intervention such as graded exercise and a psychological, social, or occupational intervention [SEP] | [CLS] described as a combination of a physical intervention such as graded exercise and a psychological, social, or occupational intervention [SEP] |
# 0.7727272727272727
# [CLS] these interventions are safe and have not been shown to increase morbidity or mortality. [SEP] | [CLS] multidisciplinary biopsychosocial rehabilitation ( described as a combination of a physical intervention such as graded exercise and a psychological, social, or occupational intervention ) [SEP] |
# 0.16326530612244897
# [CLS] these treatments are preferred over lot, and should be offered to all patients with chronic pain including those currently receiving lot. [SEP] | [CLS] exercise and psychological therapies [SEP] |
# 0.1935483870967742
# [CLS] exercise and psychological therapies [SEP] | [CLS] exercise and psychological therapies [SEP] |
# 1.0
# [CLS] in light of the low harms associated with exercise and psychological therapies when compared with lot these treatments are preferred over lot, and should be offered to all patients with chronic pain including those currently receiving lot. [SEP] | [CLS] in light of the low harms associated with exercise and psychological therapies when compared with lot [SEP] |
# 0.576271186440678
# [CLS] in light of the low harms [SEP] | [CLS] in light of the low harms associated with exercise and psychological therapies when compared with lot [SEP] |
# 0.6153846153846153
# [CLS] insufficient evidence [SEP] | [CLS] insufficient [SEP] |
# 0.8571428571428571
# [CLS] individualized [SEP] | [CLS] the choice of which to try first should be individualized based on patient assessment and a shared decision making process [SEP] |
# 0.24000000000000002
# [CLS] physical, psychological, and pain rehabilitation modalities [SEP] | [CLS] physical, psychological, and pain rehabilitation modalities [SEP] |
# 0.9
# [CLS] all avenues for obtaining these treatments ( e. g. internet based cbt ) and all appropriate non opioid medications [SEP] | [CLS] all avenues for obtaining these treatments ( e. g. internet based cbt ) and all appropriate non opioid medications [SEP] |
# 0.9130434782608695
# [CLS] continuing ot beyond 90 days ’ duration [SEP] | [CLS] continuing ot beyond 90 days ’ duration [SEP] |
# 1.0
# [CLS] continuing ot for longer than 90 days [SEP] | [CLS] continuing ot for longer than 90 days [SEP] |
# 1.0
# [CLS] that [SEP] | [CLS] there may be some situations where the benefits of lot clearly outweigh the risks. [SEP] |
# 0.2
# [CLS] individual clinical assessment [SEP] | [CLS] through individual clinical assessment [SEP] |
# 0.9090909090909091
# [CLS] that progression from acute to long - term ot is associated with little evidence for sustained analgesic efficacy but a substantial increase in risk for oud. [SEP] | [CLS] progression from acute to long - term ot is associated with little evidence for sustained analgesic efficacy but a substantial increase in risk for oud [SEP] |
# 0.9310344827586207
# [CLS] progression from acute to long - term ot [SEP] | [CLS] progression from acute to long - term ot [SEP] |
# 1.0
# [CLS] providers should discuss this information with patients at initiation of ot and continuously thereafter to ensure that the patient understands the associated risks and benefits of lot. [SEP] | [CLS] progression from acute to long - term ot is associated with little evidence for sustained analgesic efficacy but a substantial increase in risk for oud [SEP] |
# 0.20338983050847456
# [CLS] at initiation of ot and continuously thereafter [SEP] | [CLS] at initiation of ot and continuously thereafter [SEP] |
# 1.0
# [CLS] to ensure that the patient understands the associated risks and benefits of lot. [SEP] | [CLS] to ensure that the patient understands the associated risks and benefits of lot [SEP] |
# 0.9090909090909091
# [CLS] research [SEP] | [CLS] research [SEP] |
# 1.0
# [CLS] research [SEP] | [CLS] research [SEP] |
# 1.0
# [CLS] how long it takes for oud to occur [SEP] | [CLS] how long it takes for oud to occur and whether the nature of the pain is one of the factors that can influence either of this phenomena [SEP] |
# 0.5365853658536585
# [CLS] the recommendation to use non - opioid modalities in lieu of lot to treat their pain [SEP] | [CLS] the recommendation to use non - opioid modalities in lieu of lot to treat their pain [SEP] |
# 0.9473684210526315
# [CLS] va / dod sud cpg [SEP] | [CLS] the va / dod sud cpg [SEP] |
# 0.9333333333333333
# [CLS] given the increasing use of cannabis among patients with chronic pain and the lack of rcts comparing outcomes of prescribing lot versus other therapies for patients with and without cannabis use and cannabis use disorder [SEP] | [CLS] given the increasing use of cannabis among patients with chronic pain and the lack of rcts comparing outcomes of prescribing lot versus other therapies for patients with and without cannabis use and cannabis use disorder [SEP] |
# 0.7027027027027027
# [CLS] younger patients [SEP] | [CLS] younger patients using opioids [SEP] |
# 0.8
# [CLS] patients 18 - 30 years old [SEP] | [CLS] patients 18 - 30 years old [SEP] |
# 1.0
# [CLS] patients ≥65 years old [SEP] | [CLS] patients ≥65 years old [SEP] |
# 1.0
# [CLS] 11 times [SEP] | [CLS] 11 [SEP] |
# 0.8571428571428571
# [CLS] patients 31 - 40 years old [SEP] | [CLS] patients 31 - 40 years [SEP] |
# 0.9333333333333333
# [CLS] those ≥65 years old [SEP] | [CLS] those ≥65 years old [SEP] |
# 1.0
# [CLS] 5 [SEP] | [CLS] 5 [SEP] |
# 1.0
# [CLS] patients 30 - 39 years old [SEP] | [CLS] patients 30 - 39 years old [SEP] |
# 1.0
# [CLS] subjects 18 - 29 years old [SEP] | [CLS] subjects 18 - 29 years old [SEP] |
# 1.0
# [CLS] roughly half [SEP] | [CLS] roughly half [SEP] |
# 1.0
# [CLS] patients ≥70 years old [SEP] | [CLS] patients ≥70 years old [SEP] |
# 1.0
# [CLS] subjects 18 - 29 years old [SEP] | [CLS] subjects 18 - 29 years old [SEP] |
# 1.0
# [CLS] roughly half [SEP] | [CLS] far less risk ( nearly 1 / 17 ) [SEP] |
# 0.26666666666666666
# [CLS] good neurophysiologic [SEP] | [CLS] good neurophysiologic rationale [SEP] |
# 0.9090909090909091
# [CLS] studies in other areas ( e. g., use of different substances ) [SEP] | [CLS] studies in other areas ( e. g., use of different substances ) [SEP] |
# 0.9411764705882353
# [CLS] developing brains [SEP] | [CLS] developing brains ( age < 30 years ) [SEP] |
# 0.5714285714285715
# [CLS] increased risk of abnormalities and addiction [SEP] | [CLS] increased risk of abnormalities and addiction [SEP] |
# 1.0
# [CLS] age [SEP] | [CLS] age [SEP] |
# 1.0
# [CLS] there may be some variation in patient values and preferences. [SEP] | [CLS] there may be some variation [SEP] |
# 0.7000000000000001
# [CLS] patient values and preferences [SEP] | [CLS] patient values and preferences [SEP] |
# 1.0
# [CLS] state database queries [SEP] | [CLS] state database queries [SEP] |
# 1.0
# [CLS] for detection of multi - sourcing of controlled substances are used throughout the country. [SEP] | [CLS] detection of multi - sourcing of controlled substances [SEP] |
# 0.6896551724137931
# [CLS] quarterly [SEP] | [CLS] at least quarterly [SEP] |
# 0.7499999999999999
# [CLS] the cdc [SEP] | [CLS] the cdc [SEP] |
# 1.0
# [CLS] quarterly checks of the state database system [SEP] | [CLS] the state database system [SEP] |
# 0.8
# [CLS] a number of studies suggest certain chronic pain conditions represent an independent risk factor for suicide. [ 123 [SEP] | [CLS] a number of studies suggest [SEP] |
# 0.5
# [CLS] certain chronic pain conditions [SEP] | [CLS] certain chronic pain conditions [SEP] |
# 1.0
# [CLS] certain chronic pain conditions [SEP] | [CLS] an independent risk factor for suicide [SEP] |
# 0.28571428571428575
# [CLS] a recent large retrospective cohort study also suggests an association with prescribed opioid dose and suicide risk among veterans receiving ot for cncp. [SEP] | [CLS] a recent large retrospective cohort study [SEP] |
# 0.45714285714285713
# [CLS] suicide risk [SEP] | [CLS] suicide risk among veterans receiving ot for cncp [SEP] |
# 0.5333333333333333
# [CLS] prescribed opioid dose [SEP] | [CLS] prescribed opioid dose [SEP] |
# 1.0
# [CLS] suicide risk [SEP] | [CLS] suicide risk [SEP] |
# 1.0
# [CLS] an individual ’ s risk of suicide [SEP] | [CLS] an individual ’ s risk of suicide at any given point in time [SEP] |
# 0.7499999999999999
# [CLS] many factors [SEP] | [CLS] many factors [SEP] |
# 1.0
# [CLS] thus, ongoing assessment of suicide risk is important whether one is initiating, maintaining, or terminating lot. [SEP] | [CLS] suicide risk is not static, and many factors influence an individual ’ s risk of suicide at any given point in time, as noted in the va / dod suicide cpg. [SEP] |
# 0.2711864406779661
# [CLS] ongoing assessment of suicide risk [SEP] | [CLS] whether one is initiating, maintaining, or terminating lot [SEP] |
# 0.2
# [CLS] men [SEP] | [CLS] men [SEP] |
# 1.0
# [CLS] transdermal or buccal [SEP] | [CLS] either transdermal or buccal [SEP] |
# 0.9090909090909091
# [CLS] no evidence of benefit over traditional opioid delivery systems in patients with chronic pain. [SEP] | [CLS] either transdermal or buccal [SEP] |
# 0.1739130434782609
# [CLS] its : unique pharmacokinetic profile [SEP] | [CLS] unique pharmacokinetic profile, continuous delivery, even after the patch is removed due to depot effect, increased rate of delivery, unpredictable variation in rate of delivery - due to alterations in temperature due to external heat, skin integrity, and amount of adipose tissue, among patients with fever, skin damage, or cachexia [SEP] |
# 0.14705882352941174
# [CLS] include : transdermal fentanyl should not be used in opioid - naive patients [SEP] | [CLS] transdermal fentanyl should not be used in opioid - naive patients ; patients need to be informed that : heat ( e. g., sun exposure, heating pad, febrile condition ) can increase the rate and quantity of absorption, proper application includes : being sure to take old patch off ; never applying damaged patch or a patch to non - intact skin ; proper disposal to avoid exposure to children and pets, and precautions taken against possible diversion of remaining drug in used patch ; adjusted dose ( i. e., decreased patch size ) should be used in patients with renal or hepatic insufficiency and considered in elderly patients and those with febrile illness [SEP] |
# 0.19718309859154928
# [CLS] formulations of an opioid medication with a selective serotonin reuptake inhibitor ( ssri ) or a serotonin - norepinephrine reuptake inhibitor ( snri ). two common examples are tramadol and tapentadol. [SEP] | [CLS] formulations of an opioid medication with a selective serotonin reuptake inhibitor ( ssri ) or a serotonin - norepinephrine reuptake inhibitor ( snri ) [SEP] |
# 0.6363636363636364
# [CLS] two common examples are tramadol and tapentadol. [SEP] | [CLS] tramadol and tapentadol [SEP] |
# 0.6666666666666667
# [CLS] their affinity for the mu opioid receptor [SEP] | [CLS] while both are dual - mechanism opioids, they differ in their affinity for the mu opioid receptor, resulting in partial versus full agonist effects [SEP] |
# 0.4864864864864865
# [CLS] there is no long - term evidence of the comparative efficacy of tramadol versus another opioid or a non - opioid comparison such as non - steroidal anti - inflammatory drugs ( nsaids ) or acetaminophen. [SEP] | [CLS] no long - term evidence [SEP] |
# 0.2978723404255319
# [CLS] the following strategies [SEP] | [CLS] checking the pdmp, performing a udt, placement in an inpatient setting or monitored environment, and / or providing oend [SEP] |
# 0.18750000000000003
# [CLS] empathetic and non - judgmental [SEP] | [CLS] an empathetic and non - judgmental ( versus a confrontational or adversarial ) [SEP] |
# 0.6451612903225806
# F1 average score: 0.7154040500937849
# Accuracy average score:  0.8162450078673588

# %%
context = "Opioids are not first-line or routine therapy for chronic pain. Establish treatment goals before starting opioid therapy and a plan if therapy is discontinued. Only continue opioid if there is clinically meaningful improvement in pain and function. Discuss risks, benefits and responsibilities for managing therapy before starting and during treatment."
question = "When to continue opioid therapy?"
print(pipeline(question=question, context=context, max_answer_len=300, max_question_len=300))
# Out:
# {'score': 0.8287140727043152, 'start': 181, 'end': 247, 'answer': 'if there is clinically meaningful improvement in pain and function'}

# %%
#Get BLEU score
from nltk.translate.bleu_score import sentence_bleu

total_bleu = 0
for ins in eval_dataset:
  ans = pipeline(question=ins['question'], context=ins['context'], max_answer_len=350, max_question_len=50)
  bleu = sentence_bleu([ins["answer_text"]], ans["answer"])
  total_bleu += bleu

print("BLEU average score:", total_bleu / eval_dataset.num_rows)
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# BLEU average score: 0.576891102218069
